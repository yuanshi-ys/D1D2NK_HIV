# %%
# !pwd
# Out:
# /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2025/D1D2_organize/script_DNA

# %% [markdown]
# # Purpose of this notebook is to collect DNA sequence analysis spanning the course of 2024-2025, check the quality, and extract meta data

# %% [markdown]
# ## input files
# metadata is downloaded from [TCGB_deepseq_sample_list#D1D2DNABarcode](https://docs.google.com/spreadsheets/d/1XexFJ8xlxE9KBj_rNrgdMQyB6rheCKy9y-WvgEqsWmM/edit?gid=219270850#gid=219270850)

# %%
import pandas as pd
import hashlib
import json,os
from pathlib import Path
import shutil

# %%
input_path = '../csvfiles/TCGB_deepseq_sample_list - D1D2DNABarcode.csv'
reffile = pd.read_csv(input_path)

# %%
#check md5 and store
def get_file_md5(file_path):
    md5_hash = hashlib.md5()
    with open(file_path, "rb") as file:
        for chunk in iter(lambda: file.read(4096), b""):
            md5_hash.update(chunk)
    return md5_hash.hexdigest()

def store_md5_in_json(file_paths, json_output):
    md5_dict = {}
    for file_path in file_paths:
        md5_hash = get_file_md5(file_path)
        md5_dict[file_path] = md5_hash

    with open(json_output, "w") as json_file:
        json.dump(md5_dict, json_file, indent=4)

# %%
with open('../jsonfiles/notebook1_input.json','w') as f:
    json.dump({input_path:get_file_md5(input_path)},f)

# %%
# !cat ../jsonfiles/notebook1_input.json
# Out:
# {"../csvfiles/TCGB_deepseq_sample_list - D1D2DNABarcode.csv": "d489b1ef4a850c43a161223c3e6fd3f1"}

# %%
reffile = reffile[['SeqID','Index','Mouse_Cohort','MouseID','Organ','Treatment']]
reffile
# Out:
#              SeqID     Index Mouse_Cohort MouseID Organ Treatment
# 0    NovaSeq022125  Sample14      JCMMG32     #44   LIV   D1D2-NK
# 1    NovaSeq022125   Sample3      JCMMG32     #44    SP   D1D2-NK
# 2    NovaSeq022125   Sample6      JCMMG32     #44    BM   D1D2-NK
# 3    NovaSeq022625   UDP0003      JCMMG32     #44    SP   D1D2-NK
# 4    NovaSeq022625   UDP0006      JCMMG32     #44    BM   D1D2-NK
# ..             ...       ...          ...     ...   ...       ...
# 262  NovaSeq061325   UDP0043      JCMMG32     #26    BM    GFP-NK
# 263  NovaSeq061325   UDP0049       JMGA36     #30    BM     No NK
# 264  NovaSeq061325   UDP0053       JMGA36     #38    BM    GFP-NK
# 265  NovaSeq061325   UDP0098       JMGA36     #37   LIV     No NK
# 266  NovaSeq061325   UDP0100      JCMMG33      #6    BM   D1D2-NK
#
# [267 rows x 6 columns]

# %%
#take a look at the file
print ("DNA barcode has {} entries.".format(len(reffile)))
print ("That's from {} animals,".format(len(reffile.groupby(['Mouse_Cohort','MouseID']).count())),end='')
print ("{} organ samples.".format(len(reffile.groupby(['Mouse_Cohort','MouseID','Organ']).count())))
# Out:
# DNA barcode has 267 entries.
# That's from 40 animals,117 organ samples.

# %% [markdown]
# # Check sequence linkage data

# %%
SeqIDs = reffile['SeqID'].unique()

# %%
SeqIDs
# Out:
# array(['NovaSeq022125', 'NovaSeq022625', 'NovaSeq121424', 'NovaSeq043024',
#        'NovaSeq052924', 'NovaSeq061424', 'NovaSeq081324', 'NovaSeq100224',
#        'NovaSeq101624', 'NovaSeq061325'], dtype=object)

# %%
pathfile = dict()
mainpath = '/Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis'

for s in SeqIDs:
    year = '20{}'.format(s[-2:])
    path = os.path.join(mainpath,year,s,'ISS_linkage')
    if os.path.exists(path):
        print ("Found: {}".format(path))
        pathfile[s] = path
    else:
        path = os.path.join(mainpath,year,s,'ISS','ISS_linkage')
        if os.path.exists(path):
            print ("Found: {}".format(path))
            pathfile[s] = path
        else:
            print ("Data not found! {}".format(s))
# Out:
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2025/NovaSeq022125/ISS_linkage
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2025/NovaSeq022625/ISS/ISS_linkage
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2024/NovaSeq121424/ISS/ISS_linkage
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2024/NovaSeq043024/ISS_linkage
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2024/NovaSeq052924/ISS_linkage
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2024/NovaSeq061424/ISS_linkage
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2024/NovaSeq081324/ISS/ISS_linkage
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2024/NovaSeq100224/ISS/ISS_linkage
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2024/NovaSeq101624/ISS/ISS_linkage
# Found: /Users/yuanshi/Library/CloudStorage/Box-Box/Sequence Analysis/2025/NovaSeq061325/ISS/ISS_linkage

# %%
with open('../jsonfiles/pathfile.json','w') as f:
    json.dump(pathfile,f)

# %% [markdown]
# # Copy Linkage Files

# %%
Path('../linkage_files').mkdir(parents=True,exist_ok=True)

# %%
for _,entry in reffile.iterrows():
    SeqID = entry['SeqID']
    Index = entry['Index']
    linkage = os.path.join(pathfile[SeqID],'linkage_{}.txt'.format(Index))
    if os.path.exists(linkage):
        shutil.copy2(linkage, os.path.join('../linkage_files','{}_{}.txt'.format(SeqID,Index)))
    else:
        print("Not Found",entry)

# %%
#check md5
store_md5_in_json([os.path.join('../linkage_files',f) for f in os.listdir('../linkage_files') if f.endswith('txt')], '../jsonfiles/linkagefiles.json')

# %%
# !cat ../jsonfiles/linkagefiles.json
# Out:
# {
#     "../linkage_files/NovaSeq061325_UDP0034.txt": "9345f214b76a50fe738df0edde6cf318",
#     "../linkage_files/NovaSeq022125_Sample8.txt": "e8f73688e3b4e7511aa5a4db02b28493",
#     "../linkage_files/NovaSeq052924_UDP0032.txt": "d386a63e20445c97b20a3ac5a17f9612",
#     "../linkage_files/NovaSeq052924_UDP0026.txt": "526f7eb8f89c1386f7800874bdc49707",
#     "../linkage_files/NovaSeq022125_Sample38.txt": "ffd3a42307ebf34197af6c712fbb9d39",
#     "../linkage_files/NovaSeq022125_Sample10.txt": "124971608854a8d97c43bf9e3d7b3027",
#     "../linkage_files/NovaSeq121424_JK1.txt": "a748e1b385c59d54237ae45591a2912c",
#     "../linkage_files/NovaSeq061424_UDP0062.txt": "c487d34e204bc83feae332c784ee1c70",
#     "../linkage_files/NovaSeq081324_UDP0029.txt": "a19155b7ab3dc3aa7a61a54c6402c8d9",
#     "../linkage_files/NovaSeq101624_UDP0081.txt": "c0b0f8b2eadddcc4c4bc6a42018f6dc3",
#     "../linkage_files/NovaSeq043024_UDP0025.txt": "d26e0c1958886e56ba0fa852fa91a9ba",
#     "../linkage_files/NovaSeq043024_UDP0030.txt": "f7e5a35ac5f5626b819c53391c39cc93",
#     "../linkage_files/NovaSeq022125_Sample81.txt": "cc55d5ea51e3cdc371bc890d97f0df62",
#     "../linkage_files/NovaSeq022125_Sample56.txt": "67fd1bef22ce478c902af70e3fac9372",
#     "../linkage_files/NovaSeq022125_Sample42.txt": "35169199bd49009231d960965d9c81e2",
#     "../linkage_files/NovaSeq052924_UDP0048.txt": "b84ed9fa304e81bf76ed07c62bfa13bd",
#     "../linkage_files/NovaSeq061325_UDP0015.txt": "c50efe8a3008e7a3f1f2cf1ee1c785b3",
#     "../linkage_files/NovaSeq022125_Sample1.txt": "d94b7ab96c3172e10dc04265af229ce7",
#     "../linkage_files/NovaSeq052924_UDP0013.txt": "8f4e829ccc0f734a14fe08a4df2ae9f3",
#     "../linkage_files/NovaSeq022125_Sample19.txt": "bd49fd71d1991f8401549ff3a85b908f",
#     "../linkage_files/NovaSeq022125_Sample25.txt": "5140fb2c2ebf20cfbcbeec2e8485e003",
#     "../linkage_files/NovaSeq022125_Sample31.txt": "5a4afb8677987af2296aed021054e8d7",
#     "../linkage_files/NovaSeq061424_UDP0043.txt": "69deb9cae33e76ace22f9ffd9d6153c3",
#     "../linkage_files/NovaSeq022625_UDP0005.txt": "2e437d9b86b5b27188a098c3d8394d32",
#     "../linkage_files/NovaSeq022625_UDP0011.txt": "459a9b1de99fd57dc5a518c010f4af3b",
#     "../linkage_files/NovaSeq121424_JK41.txt": "7efb6af8cfd8be324f6f5d21184323f3",
#     "../linkage_files/NovaSeq043024_UDP0004.txt": "473ac8a7cea5984e7c5dc9069794901d",
#     "../linkage_files/NovaSeq043024_UDP0005.txt": "68aeadcad6cc6b457cdbe263872b5e50",
#     "../linkage_files/NovaSeq043024_UDP0039.txt": "6af53ad5d46ce3218fb4f390dabc95cd",
#     "../linkage_files/NovaSeq121424_JK40.txt": "06fae0adeda5faf0f86a12271089a742",
#     "../linkage_files/NovaSeq022625_UDP0010.txt": "46497d868cd68d0874418a9ad507e9df",
#     "../linkage_files/NovaSeq022625_UDP0004.txt": "2265e43d66f95505c354fe1a0e1136a3",
#     "../linkage_files/NovaSeq061424_UDP0056.txt": "a4ae9ff55edf9f4b04b9f1f956c11691",
#     "../linkage_files/NovaSeq061424_UDP0042.txt": "74dc52847cb5cb9d2900ecac572e7217",
#     "../linkage_files/NovaSeq121424_JK9.txt": "2aad1b95e61ae274f78ba146eba0333e",
#     "../linkage_files/NovaSeq022125_Sample30.txt": "d656ad38ff2952a42cc4b79acbb8dd37",
#     "../linkage_files/NovaSeq022125_Sample24.txt": "135d9ab95f55fbe44649181980698aa3",
#     "../linkage_files/NovaSeq022125_Sample18.txt": "fef83e350c9e466ab8f511a3e5f3bbbd",
#     "../linkage_files/NovaSeq052924_UDP0006.txt": "b215e95228f675378c8bf4537371e741",
#     "../linkage_files/NovaSeq052924_UDP0012.txt": "bfc4f0adba85a4de6f391a56c5c9671e",
#     "../linkage_files/NovaSeq061325_UDP0016.txt": "55f6bef095ba3e72b8e21838ffaf340d",
#     "../linkage_files/NovaSeq022125_Sample2.txt": "a35575d01b7191fddcf1a82a17051327",
#     "../linkage_files/NovaSeq052924_UDP0004.txt": "c175a324d80dd56374c0298702ad6827",
#     "../linkage_files/NovaSeq022125_Sample32.txt": "cf49b1d0ee3e6e577fd6dbc336462230",
#     "../linkage_files/NovaSeq022125_Sample26.txt": "e6f4cb06cdf2f60115fd4c498ffee210",
#     "../linkage_files/NovaSeq061424_UDP0054.txt": "75e1a8c60ecbb78bb410135912dd5aba",
#     "../linkage_files/NovaSeq061424_UDP0040.txt": "365fc4234046744c16385ce6ad809bb8",
#     "../linkage_files/NovaSeq100224_UDP0071.txt": "40d9b5ff5529802938d4aa73873662e9",
#     "../linkage_files/NovaSeq022625_UDP0012.txt": "8f8356e168460f76a4c30dfaa11e4f5e",
#     "../linkage_files/NovaSeq022625_UDP0006.txt": "a7ebe9fe4b7272c584fb6fc725023d2d",
#     "../linkage_files/NovaSeq043024_UDP0013.txt": "9b8465f416fe3c5e397ae36acb8fb40d",
#     "../linkage_files/NovaSeq043024_UDP0012.txt": "255d0eec6e1c8940d002b0c80ca4dc3e",
#     "../linkage_files/NovaSeq043024_UDP0006.txt": "7641e26f07538b75b261e3a6f111e024",
#     "../linkage_files/NovaSeq022625_UDP0007.txt": "374ab076f146fca5e22b49bbcbb1297f",
#     "../linkage_files/NovaSeq022625_UDP0013.txt": "b53762abec292f1128806a9b91863074",
#     "../linkage_files/NovaSeq100224_UDP0070.txt": "60ee687e9150e5ad743772009a4aa75d",
#     "../linkage_files/NovaSeq061424_UDP0041.txt": "aba65ec0f3cde6ef2bfffaa60faf3a69",
#     "../linkage_files/NovaSeq022125_Sample27.txt": "fd9b689f8e25841acb94688a308c320c",
#     "../linkage_files/NovaSeq022125_Sample33.txt": "1f0ce737c66a057f3be6593f52fba19d",
#     "../linkage_files/NovaSeq052924_UDP0005.txt": "610b2e8b1bb1b84746bd61cb02c5094c",
#     "../linkage_files/NovaSeq052924_UDP0039.txt": "f2116a154f85cecda8a8eee0d2bcf0fe",
#     "../linkage_files/NovaSeq022125_Sample3.txt": "5edce0f46bfe321ab38bd78f75280816",
#     "../linkage_files/NovaSeq061325_UDP0017.txt": "62bb3818e0631ca22632cab95bb88f00",
#     "../linkage_files/NovaSeq022125_Sample7.txt": "028a94adf7a24dc42935bc589d48e160",
#     "../linkage_files/NovaSeq052924_UDP0001.txt": "34e7e0fad644d9c414fe1b21b779cfa2",
#     "../linkage_files/NovaSeq022125_Sample37.txt": "5940ed3978fcb4886ff111a0cbec2816",
#     "../linkage_files/NovaSeq022625_UDP0003.txt": "19775cf39b06307e6160917bdc5c100b",
#     "../linkage_files/NovaSeq043024_UDP0017.txt": "7a3077a3e18542029cfafc040fe5c6ab",
#     "../linkage_files/NovaSeq022625_UDP0002.txt": "439b0fa9320e97574b565077aa52ddb7",
#     "../linkage_files/NovaSeq101624_UDP0070.txt": "35eb2276715fbc8ea3455be9a0c8056c",
#     "../linkage_files/NovaSeq022625_UDP0016.txt": "c916ed7ae451685e90c078bc52659c09",
#     "../linkage_files/NovaSeq061424_UDP0050.txt": "ad44b3d03d44218af03b28c101964498",
#     "../linkage_files/NovaSeq022125_Sample22.txt": "e31b18cf37891bf8384313d75c5c8e90",
#     "../linkage_files/NovaSeq022125_Sample36.txt": "f813e38af7350a78882f7ff1ba447c75",
#     "../linkage_files/NovaSeq052924_UDP0028.txt": "5a74b59db19d14a3a780e33274c4b6d9",
#     "../linkage_files/NovaSeq052924_UDP0014.txt": "63ef6501e4ffd4c852db900436450c8f",
#     "../linkage_files/NovaSeq022125_Sample6.txt": "a3b5d3ec8a8be1b83acbfa020f825c9b",
#     "../linkage_files/NovaSeq022125_Sample4.txt": "5925feee222dde793fc10e1eeb96ac33",
#     "../linkage_files/NovaSeq061325_UDP0038.txt": "f885497d5ae505b23c15d47bf64ac8af",
#     "../linkage_files/NovaSeq022125_Sample20.txt": "d5ac6146fad7867d4ca38bb82455df17",
#     "../linkage_files/NovaSeq022125_Sample34.txt": "80bde67ebb9660cb60b374ed8429f58a",
#     "../linkage_files/NovaSeq061424_UDP0046.txt": "24adfc104946dbce0aede96cecf2c628",
#     "../linkage_files/NovaSeq061424_UDP0052.txt": "40a7ce7682e31b8bcffd51d79f1f2c95",
#     "../linkage_files/NovaSeq022625_UDP0014.txt": "236ee99b05e5f979cd822fda82ef4c48",
#     "../linkage_files/NovaSeq081324_UDP0031.txt": "fce0e4e02372c2c969be80ecf9c413a9",
#     "../linkage_files/NovaSeq043024_UDP0001.txt": "57466e299bf0bb809c662227427e7eb5",
#     "../linkage_files/NovaSeq043024_UDP0028.txt": "800e159875857ca4c707485d4dff1996",
#     "../linkage_files/NovaSeq043024_UDP0014.txt": "d1a34ad9aba3c63a2b53f492143229ee",
#     "../linkage_files/NovaSeq081324_UDP0030.txt": "8c571a4589224764cad09cc552acc113",
#     "../linkage_files/NovaSeq022625_UDP0015.txt": "18faffb1f8b8512db190d7b0a8b04819",
#     "../linkage_files/NovaSeq061424_UDP0053.txt": "f61a2121b89833747843906db2aa4451",
#     "../linkage_files/NovaSeq022125_Sample35.txt": "e715fb9b4c72eeeae196f949a98ca2f4",
#     "../linkage_files/NovaSeq022125_Sample21.txt": "902fafb28ba14eb170e9a8ade77e2d3b",
#     "../linkage_files/NovaSeq052924_UDP0017.txt": "b718c525c433aa547c9732bf2cf1057e",
#     "../linkage_files/NovaSeq061325_UDP0039.txt": "9384c1298b604a6f12853d28be0a35aa",
#     "../linkage_files/NovaSeq022125_Sample5.txt": "ab34f508cc5c3d2deccda3ef7ddbb5f1"
# }

# %%
import pickle
with open('../picklefiles/notebook1.pkl','wb') as f:
    pickle.dump({'reffile':reffile},f)
